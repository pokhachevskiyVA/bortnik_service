# %%
# %%time
import sys
sys.path.append("../../")
from analytics_lib.nlp_texts.API import api
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# CPU times: user 9.76 s, sys: 2.37 s, total: 12.1 s
# Wall time: 11.4 s

# %%
# %%time
text = "Программа \"Вернём клиентов\" для дилеров ГаражТулс.В рамках развития дилерской сети за дополнительные деньги настроить триггерную рассылку для тех клиентов, которые ушли.\
Тестируем: берем лояльного дилера, предлагаем в качестве эксперимента предоставить нам клиентов, которые отказались от покупки (на их сайте или магазине). Собираем контакты, настраиваем триггерную рассылку. Смотрим на результат. Если успех, то проводим опрос на основных дилерах и показываем успешный кейс. Узнаем, сколько бы они заплатили за это. Дальше пробуем продать 2-3- дилерам такую услугу. (пока делаем всё вручную) Если они оплачивают, то гипотезу можно считать проверенной и можно запускать в разработку функционал.(и если юнит экономика сходится)Подключаем дилерскую CRM (или любую другую систему, где есть отвалившиеся клиенты) к системе триггерных рассылок. К пакету дилерских документов предлагаем новую услугу. Непринужденно зарабатываем."
print(text)
dict_res = api(text=text, quantiles="assessty_short") # quantiles: 'assessty_all', "assessty_short", 'dialogs'
# Out:
# Программа "Вернём клиентов" для дилеров ГаражТулс.В рамках развития дилерской сети за дополнительные деньги настроить триггерную рассылку для тех клиентов, которые ушли.Тестируем: берем лояльного дилера, предлагаем в качестве эксперимента предоставить нам клиентов, которые отказались от покупки (на их сайте или магазине). Собираем контакты, настраиваем триггерную рассылку. Смотрим на результат. Если успех, то проводим опрос на основных дилерах и показываем успешный кейс. Узнаем, сколько бы они заплатили за это. Дальше пробуем продать 2-3- дилерам такую услугу. (пока делаем всё вручную) Если они оплачивают, то гипотезу можно считать проверенной и можно запускать в разработку функционал.(и если юнит экономика сходится)Подключаем дилерскую CRM (или любую другую систему, где есть отвалившиеся клиенты) к системе триггерных рассылок. К пакету дилерских документов предлагаем новую услугу. Непринужденно зарабатываем.
# 2023-02-28 19:58:25.900358: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# CPU times: user 29.2 s, sys: 8.08 s, total: 37.3 s
# Wall time: 29.7 s

# %%
dict_res
# Out:
# {'Текст': 'Программа "Вернём клиентов" для дилеров ГаражТулс.В рамках развития дилерской сети за дополнительные деньги настроить триггерную рассылку для тех клиентов, которые ушли.Тестируем: берем лояльного дилера, предлагаем в качестве эксперимента предоставить нам клиентов, которые отказались от покупки (на их сайте или магазине). Собираем контакты, настраиваем триггерную рассылку. Смотрим на результат. Если успех, то проводим опрос на основных дилерах и показываем успешный кейс. Узнаем, сколько бы они заплатили за это. Дальше пробуем продать 2-3- дилерам такую услугу. (пока делаем всё вручную) Если они оплачивают, то гипотезу можно считать проверенной и можно запускать в разработку функционал.(и если юнит экономика сходится)Подключаем дилерскую CRM (или любую другую систему, где есть отвалившиеся клиенты) к системе триггерных рассылок. К пакету дилерских документов предлагаем новую услугу. Непринужденно зарабатываем.',
#  'Интервалы для темпераментов': {'Общее количество слов в тексте': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля предложений на одно слово': {'Меланхолик': 'Меньше среднего: (0.06, 0.08)',
#    'Холерик': 'Больше среднего: (0.1, 0.12)',
#    'Флегматик': 'Мало: (0.02, 0.06)',
#    'Сангвиник': 'Много: (0.12, 0.25)'},
#   'Доля коротких предложений': {'Меланхолик': 'Среднее: (0.33, 0.5)',
#    'Холерик': 'Среднее: (0.33, 0.5)',
#    'Флегматик': 'Много: (0.75, 1.57)',
#    'Сангвиник': 'Мало: (0.0, 0.14)'},
#   'Доля длинных предложений': {'Меланхолик': 'Мало: (0.0, 0.25)',
#    'Холерик': 'Больше среднего: (0.57, 0.75)',
#    'Флегматик': 'Мало: (0.0, 0.25)',
#    'Сангвиник': 'Много: (0.75, 1.0)'},
#   'Доля длинных низкочастотных слов': {'Меланхолик': 'Среднее: (0.11, 0.13)',
#    'Холерик': 'Мало: (0.0, 0.08)',
#    'Флегматик': 'Мало: (0.0, 0.08)',
#    'Сангвиник': 'Много: (0.18, 0.28)'},
#   'Доля коротких высокочастотных слов': {'Меланхолик': '-',
#    'Холерик': 'Много: (0.58, 1.0)',
#    'Флегматик': 'Среднее: (0.48, 0.53)',
#    'Сангвиник': '-'},
#   'Средняя длина предложения': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее число запятых в предложении': {'Меланхолик': '-',
#    'Холерик': 'Больше среднего: (1.25, 1.82)',
#    'Флегматик': 'Больше среднего: (1.25, 1.82)',
#    'Сангвиник': '-'},
#   'Доля сложноподчиненных предложений': {'Меланхолик': 'Среднее: (0.17, 0.29)',
#    'Холерик': 'Мало: (0.0, 0.0)',
#    'Флегматик': 'Мало: (0.0, 0.0)',
#    'Сангвиник': 'Много: (0.5, 1.0)'},
#   'Доля восклицательных предложений': {'Меланхолик': 'Мало: (0.0, 0.0)',
#    'Холерик': 'Много: (0.0, 0.5)',
#    'Флегматик': '-',
#    'Сангвиник': 'Среднее: (0.0, 0.0)'},
#   'Доля вопросительных предложений': {'Меланхолик': 'Много: (0.0, 0.38)',
#    'Холерик': 'Много: (0.0, 0.38)',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля частиц НЕ': {'Меланхолик': 'Мало: (0.0, 0.0)',
#    'Холерик': 'Среднее: (0.0, 0.0)',
#    'Флегматик': 'Много: (0.25, 1.0)',
#    'Сангвиник': '-'},
#   'Cредняя длинна слова в тексте': {'Меланхолик': 'Меньше среднего: (6.62, 6.95)',
#    'Холерик': 'Больше среднего: (7.32, 7.82)',
#    'Флегматик': 'Мало: (4.79, 6.62)',
#    'Сангвиник': 'Много: (7.82, 9.05)'},
#   'Гласные, %': {'Меланхолик': 'Больше среднего: (42.0, 43.0)',
#    'Холерик': 'Больше среднего: (42.0, 43.0)',
#    'Флегматик': 'Меньше среднего: (41.0, 42.0)',
#    'Сангвиник': 'Меньше среднего: (41.0, 42.0)'},
#   'Гласная "И", %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': 'Много: (9.0, 13)'},
#   'Гласная "О", %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Гласная "А", %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': 'Много: (8.0, 12)',
#    'Сангвиник': '-'},
#   'Согласные, %': {'Меланхолик': 'Меньше среднего: (55.0, 56.0)',
#    'Холерик': 'Меньше среднего: (55.0, 56.0)',
#    'Флегматик': 'Больше среднего: (56.0, 57.0)',
#    'Сангвиник': 'Больше среднего: (56.0, 57.0)'},
#   'Существительные, %': {'Меланхолик': 'Больше среднего: (48.33, 54.55)',
#    'Холерик': 'Меньше среднего: (35.43, 42.44)',
#    'Флегматик': 'Много: (54.55, 77.08)',
#    'Сангвиник': 'Среднее: (42.44, 48.33)'},
#   'Глаголы, %': {'Меланхолик': 'Меньше среднего: (11.79, 15.62)',
#    'Холерик': 'Среднее: (15.62, 19.66)',
#    'Флегматик': 'Меньше среднего: (11.79, 15.62)',
#    'Сангвиник': 'Больше среднего: (19.66, 24.77)'},
#   'Совершенный вид, %': {'Меланхолик': 'Меньше среднего: (27.14, 50.91)',
#    'Холерик': 'Меньше среднего: (27.14, 50.91)',
#    'Флегматик': 'Много: (85.71, 100.0)',
#    'Сангвиник': 'Больше среднего: (69.13, 85.71)'},
#   'Несовершенный вид, %': {'Меланхолик': 'Больше среднего: (40.73, 66.67)',
#    'Холерик': 'Больше среднего: (40.73, 66.67)',
#    'Флегматик': 'Мало: (0.0, 12.5)',
#    'Сангвиник': 'Меньше среднего: (12.5, 25.0)'},
#   'Прилагательные, %': {'Меланхолик': 'Много: (15.48, 27.03)',
#    'Холерик': 'Меньше среднего: (6.38, 8.9)',
#    'Флегматик': 'Больше среднего: (12.5, 15.48)',
#    'Сангвиник': 'Среднее: (8.9, 12.5)'},
#   'Степени сравнения, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Превосходная степень, %': {'Меланхолик': '-',
#    'Холерик': 'Больше среднего: (0.0, 0.0)',
#    'Флегматик': 'Больше среднего: (0.0, 0.0)',
#    'Сангвиник': '-'},
#   'Сравнительная степень, %': {'Меланхолик': 'Больше среднего: (0.0, 50.0)',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': 'Больше среднего: (0.0, 50.0)'},
#   'Наречия, %': {'Меланхолик': 'Меньше среднего: (1.76, 3.14)',
#    'Холерик': 'Много: (8.16, 23.68)',
#    'Флегматик': 'Среднее: (3.14, 5.54)',
#    'Сангвиник': 'Больше среднего: (5.54, 8.16)'},
#   'Причастия, %': {'Меланхолик': 'Мало: (0.0, 0.0)',
#    'Холерик': 'Больше среднего: (2.17, 3.53)',
#    'Флегматик': 'Мало: (0.0, 0.0)',
#    'Сангвиник': 'Много: (3.53, 18.42)'},
#   'Деепричастия, %': {'Меланхолик': 'Мало: (0.0, 0.0)',
#    'Холерик': 'Больше среднего: (0.0, 0.0)',
#    'Флегматик': 'Мало: (0.0, 0.0)',
#    'Сангвиник': 'Много: (0.0, 9.09)'},
#   'Наклонения, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Изъявительное наклонение, %': {'Меланхолик': 'Много: (100.0, 100.0)',
#    'Холерик': 'Много: (100.0, 100.0)',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Условное наклонение, %': {'Меланхолик': 'Много: (12.5, 50.0)',
#    'Холерик': 'Среднее: (0.0, 0.0)',
#    'Флегматик': 'Мало: (0.0, 0.0)',
#    'Сангвиник': '-'},
#   'Повелительное наклонение, %': {'Меланхолик': 'Мало: (0.0, 0.0)',
#    'Холерик': 'Мало: (0.0, 0.0)',
#    'Флегматик': 'Много: (0.0, 40.0)',
#    'Сангвиник': 'Мало: (0.0, 0.0)'},
#   'Среднее количество слов в предложении': {'Меланхолик': 'Меньше среднего: (8.0, 9.82)',
#    'Холерик': 'Больше среднего: (12.47, 16.33)',
#    'Флегматик': 'Мало: (4.0, 8.0)',
#    'Сангвиник': 'Много: (16.33, 63.0)'},
#   'Средняя доля именованных сущностей в предложении': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее количество морфем в слове': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Средняя частота TOP10 самых редких слов в тексте': {'Меланхолик': 'Меньше среднего: (2.46, 2.8)',
#    'Холерик': 'Больше среднего: (3.02, 3.26)',
#    'Флегматик': 'Мало: (0.67, 2.46)',
#    'Сангвиник': 'Много: (3.26, 5.69)'},
#   'Среднее число синтаксических веток (по предложениям)': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее число синтаксических веток (на одно слово)': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Средняя глубина синтаксической ветки': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее число прилагательных в синтаксической ветке': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее число причастий в синтаксической ветке': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее число деепричастий в синтаксической ветке': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Водность текста': {'Меланхолик': '-',
#    'Холерик': 'Мало: (0.0, 0.05)',
#    'Флегматик': 'Много: (0.19, 0.4)',
#    'Сангвиник': 'Много: (0.19, 0.4)'},
#   'Вариабельность словаря': {'Меланхолик': 'Больше среднего: (0.86, 0.91)',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': 'Больше среднего: (0.86, 0.91)'},
#   'Доля повторов в тексте': {'Меланхолик': 'Мало: (0.0, 0.08)',
#    'Холерик': 'Больше среднего: (0.13, 0.16)',
#    'Флегматик': 'Больше среднего: (0.13, 0.16)',
#    'Сангвиник': 'Мало: (0.0, 0.08)'},
#   'Доля местоимений Я': {'Меланхолик': 'Много: (0.0, 0.06)',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': 'Много: (0.0, 0.06)'},
#   'Классическая тошнота': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Академическая тошнота': {'Меланхолик': 'Среднее: (0.19, 0.22)',
#    'Холерик': '-',
#    'Флегматик': 'Много: (0.26, 0.34)',
#    'Сангвиник': 'Много: (0.26, 0.34)'},
#   'Доля местоимений в тексте': {'Меланхолик': 'Среднее: (0.03, 0.06)',
#    'Холерик': 'Меньше среднего: (0.02, 0.03)',
#    'Флегматик': 'Больше среднего: (0.06, 0.09)',
#    'Сангвиник': 'Много: (0.09, 0.3)'},
#   'Доля частиц в тексте': {'Меланхолик': 'Больше среднего: (0.02, 0.04)',
#    'Холерик': 'Среднее: (0.0, 0.02)',
#    'Флегматик': 'Меньше среднего: (0.0, 0.0)',
#    'Сангвиник': 'Больше среднего: (0.02, 0.04)'},
#   'Собственные/Нарицательные': {'Меланхолик': 'Больше среднего: (0.0, 0.0)',
#    'Холерик': 'Больше среднего: (0.0, 0.0)',
#    'Флегматик': 'Мало: (0.0, 0.0)',
#    'Сангвиник': '-'},
#   'Доля числительных в тексте': {'Меланхолик': 'Мало: (0.0, 0.0)',
#    'Холерик': 'Больше среднего: (0.0, 0.04)',
#    'Флегматик': 'Больше среднего: (0.0, 0.04)',
#    'Сангвиник': '-'},
#   'Доля междометий в тексте': {'Меланхолик': 'Мало: (0.0, 0.0)',
#    'Холерик': 'Среднее: (0.0, 0.0)',
#    'Флегматик': 'Больше среднего: (0.0, 0.0)',
#    'Сангвиник': 'Мало: (0.0, 0.0)'},
#   'Доля союзов в тексте': {'Меланхолик': '-',
#    'Холерик': 'Мало: (0.0, 0.03)',
#    'Флегматик': 'Много: (0.09, 0.18)',
#    'Сангвиник': 'Больше среднего: (0.06, 0.09)'},
#   'Доля предлогов в тексте': {'Меланхолик': 'Много: (0.18, 0.33)',
#    'Холерик': '-',
#    'Флегматик': 'Много: (0.18, 0.33)',
#    'Сангвиник': 'Мало: (0.0, 0.09)'},
#   'Агенс': {'Меланхолик': 'Мало: (0.0, 0.0)',
#    'Холерик': 'Много: (0.6, 1.6)',
#    'Флегматик': 'Мало: (0.0, 0.0)',
#    'Сангвиник': 'Больше среднего: (0.2, 0.6)'},
#   'Пациенс': {'Меланхолик': 'Много: (1.0, 2.0)',
#    'Холерик': 'Меньше среднего: (0.4, 0.8)',
#    'Флегматик': 'Много: (1.0, 2.0)',
#    'Сангвиник': 'Среднее: (0.8, 1.0)'},
#   'Внутренний предикат': {'Меланхолик': 'Много: (0.2, 1.0)',
#    'Холерик': 'Мало: (0.0, 0.0)',
#    'Флегматик': 'Среднее: (0.0, 0.1)',
#    'Сангвиник': 'Больше среднего: (0.1, 0.2)'},
#   'Внешний предикат': {'Меланхолик': 'Больше среднего: (0.4, 0.6)',
#    'Холерик': 'Много: (0.6, 1.1)',
#    'Флегматик': 'Среднее: (0.3, 0.4)',
#    'Сангвиник': 'Меньше среднего: (0.1, 0.3)'}},
#  'Интервалы для психотипов': {'Общее количество слов в тексте': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля предложений на одно слово': {'Истероид': 'Больше среднего: (0.1, 0.12)',
#    'Гипертим': '-',
#    'Шизоид': 'Много: (0.12, 0.25)',
#    'Параноял': '-',
#    'Эпилептоид': 'Мало: (0.02, 0.06)',
#    'Депрессивный': '-',
#    'Эмотив': 'Меньше среднего: (0.06, 0.08)',
#    'Тревожный': '-'},
#   'Доля коротких предложений': {'Истероид': 'Среднее: (0.33, 0.5)',
#    'Гипертим': 'Много: (0.75, 1.57)',
#    'Шизоид': 'Мало: (0.0, 0.14)',
#    'Параноял': 'Среднее: (0.33, 0.5)',
#    'Эпилептоид': 'Много: (0.75, 1.57)',
#    'Депрессивный': '-',
#    'Эмотив': 'Среднее: (0.33, 0.5)',
#    'Тревожный': 'Мало: (0.0, 0.14)'},
#   'Доля длинных предложений': {'Истероид': 'Больше среднего: (0.57, 0.75)',
#    'Гипертим': '-',
#    'Шизоид': 'Много: (0.75, 1.0)',
#    'Параноял': 'Мало: (0.0, 0.25)',
#    'Эпилептоид': 'Мало: (0.0, 0.25)',
#    'Депрессивный': '-',
#    'Эмотив': 'Мало: (0.0, 0.25)',
#    'Тревожный': 'Много: (0.75, 1.0)'},
#   'Доля длинных низкочастотных слов': {'Истероид': 'Мало: (0.0, 0.08)',
#    'Гипертим': 'Меньше среднего: (0.08, 0.11)',
#    'Шизоид': 'Много: (0.18, 0.28)',
#    'Параноял': 'Мало: (0.0, 0.08)',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': 'Больше среднего: (0.13, 0.18)',
#    'Тревожный': 'Много: (0.18, 0.28)'},
#   'Доля коротких высокочастотных слов': {'Истероид': 'Много: (0.58, 1.0)',
#    'Гипертим': 'Много: (0.58, 1.0)',
#    'Шизоид': 'Мало: (0.27, 0.43)',
#    'Параноял': 'Среднее: (0.48, 0.53)',
#    'Эпилептоид': 'Много: (0.58, 1.0)',
#    'Депрессивный': '-',
#    'Эмотив': 'Среднее: (0.48, 0.53)',
#    'Тревожный': 'Мало: (0.27, 0.43)'},
#   'Средняя длина предложения': {'Истероид': 'Больше среднего: (12.47, 16.33)',
#    'Гипертим': '-',
#    'Шизоид': 'Много: (16.33, 63.0)',
#    'Параноял': '-',
#    'Эпилептоид': 'Мало: (4.0, 8.0)',
#    'Депрессивный': '-',
#    'Эмотив': 'Меньше среднего: (8.0, 9.82)',
#    'Тревожный': '-'},
#   'Среднее число запятых в предложении': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля сложноподчиненных предложений': {'Истероид': 'Мало: (0.0, 0.0)',
#    'Гипертим': 'Мало: (0.0, 0.0)',
#    'Шизоид': 'Много: (0.5, 1.0)',
#    'Параноял': 'Среднее: (0.17, 0.29)',
#    'Эпилептоид': 'Мало: (0.0, 0.0)',
#    'Депрессивный': '-',
#    'Эмотив': 'Среднее: (0.17, 0.29)',
#    'Тревожный': 'Много: (0.5, 1.0)'},
#   'Доля восклицательных предложений': {'Истероид': 'Много: (0.0, 0.5)',
#    'Гипертим': 'Мало: (0.0, 0.0)',
#    'Шизоид': 'Мало: (0.0, 0.0)',
#    'Параноял': 'Много: (0.0, 0.5)',
#    'Эпилептоид': 'Много: (0.0, 0.5)',
#    'Депрессивный': '-',
#    'Эмотив': 'Мало: (0.0, 0.0)',
#    'Тревожный': 'Мало: (0.0, 0.0)'},
#   'Доля вопросительных предложений': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': 'Много: (0.0, 0.38)',
#    'Депрессивный': '-',
#    'Эмотив': 'Много: (0.0, 0.38)',
#    'Тревожный': 'Много: (0.0, 0.38)'},
#   'Доля частиц НЕ': {'Истероид': 'Среднее: (0.0, 0.0)',
#    'Гипертим': 'Мало: (0.0, 0.0)',
#    'Шизоид': '-',
#    'Параноял': 'Много: (0.25, 1.0)',
#    'Эпилептоид': 'Много: (0.25, 1.0)',
#    'Депрессивный': 'Много: (0.25, 1.0)',
#    'Эмотив': 'Мало: (0.0, 0.0)',
#    'Тревожный': 'Много: (0.25, 1.0)'},
#   'Cредняя длинна слова в тексте': {'Истероид': 'Больше среднего: (7.32, 7.82)',
#    'Гипертим': '-',
#    'Шизоид': 'Много: (7.82, 9.05)',
#    'Параноял': '-',
#    'Эпилептоид': 'Мало: (4.79, 6.62)',
#    'Депрессивный': '-',
#    'Эмотив': 'Меньше среднего: (6.62, 6.95)',
#    'Тревожный': '-'},
#   'Гласные, %': {'Истероид': 'Больше среднего: (42.0, 43.0)',
#    'Гипертим': 'Среднее: (42.0, 42.0)',
#    'Шизоид': 'Меньше среднего: (41.0, 42.0)',
#    'Параноял': 'Мало: (36, 41.0)',
#    'Эпилептоид': 'Меньше среднего: (41.0, 42.0)',
#    'Депрессивный': '-',
#    'Эмотив': 'Больше среднего: (42.0, 43.0)',
#    'Тревожный': 'Много: (43.0, 47)'},
#   'Гласная "И", %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': 'Много: (9.0, 13)',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Гласная "О", %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': 'Много: (12.0, 15)',
#    'Тревожный': '-'},
#   'Гласная "А", %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': 'Много: (8.0, 12)',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Согласные, %': {'Истероид': 'Меньше среднего: (55.0, 56.0)',
#    'Гипертим': 'Среднее: (56.0, 56.0)',
#    'Шизоид': 'Больше среднего: (56.0, 57.0)',
#    'Параноял': 'Много: (57.0, 62)',
#    'Эпилептоид': 'Больше среднего: (56.0, 57.0)',
#    'Депрессивный': '-',
#    'Эмотив': 'Меньше среднего: (55.0, 56.0)',
#    'Тревожный': 'Мало: (51, 55.0)'},
#   'Существительные, %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': 'Много: (54.55, 77.08)',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Глаголы, %': {'Истероид': 'Меньше среднего: (11.79, 15.62)',
#    'Гипертим': 'Много: (24.77, 38.64)',
#    'Шизоид': 'Мало: (0.0, 11.79)',
#    'Параноял': 'Много: (24.77, 38.64)',
#    'Эпилептоид': 'Много: (24.77, 38.64)',
#    'Депрессивный': '-',
#    'Эмотив': 'Мало: (0.0, 11.79)',
#    'Тревожный': 'Мало: (0.0, 11.79)'},
#   'Совершенный вид, %': {'Истероид': 'Меньше среднего: (27.14, 50.91)',
#    'Гипертим': '-',
#    'Шизоид': 'Больше среднего: (69.13, 85.71)',
#    'Параноял': '-',
#    'Эпилептоид': 'Много: (85.71, 100.0)',
#    'Депрессивный': '-',
#    'Эмотив': 'Меньше среднего: (27.14, 50.91)',
#    'Тревожный': '-'},
#   'Несовершенный вид, %': {'Истероид': 'Больше среднего: (40.73, 66.67)',
#    'Гипертим': '-',
#    'Шизоид': 'Меньше среднего: (12.5, 25.0)',
#    'Параноял': '-',
#    'Эпилептоид': 'Мало: (0.0, 12.5)',
#    'Депрессивный': '-',
#    'Эмотив': 'Больше среднего: (40.73, 66.67)',
#    'Тревожный': '-'},
#   'Прилагательные, %': {'Истероид': 'Много: (15.48, 27.03)',
#    'Гипертим': 'Мало: (0.0, 6.38)',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': 'Мало: (0.0, 6.38)',
#    'Депрессивный': '-',
#    'Эмотив': 'Много: (15.48, 27.03)',
#    'Тревожный': 'Мало: (0.0, 6.38)'},
#   'Степени сравнения, %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Превосходная степень, %': {'Истероид': 'Больше среднего: (0.0, 0.0)',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': 'Больше среднего: (0.0, 0.0)',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Сравнительная степень, %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': 'Больше среднего: (0.0, 50.0)',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': 'Больше среднего: (0.0, 50.0)',
#    'Тревожный': '-'},
#   'Наречия, %': {'Истероид': 'Много: (8.16, 23.68)',
#    'Гипертим': 'Меньше среднего: (1.76, 3.14)',
#    'Шизоид': 'Больше среднего: (5.54, 8.16)',
#    'Параноял': '-',
#    'Эпилептоид': 'Мало: (0.0, 1.76)',
#    'Депрессивный': '-',
#    'Эмотив': 'Мало: (0.0, 1.76)',
#    'Тревожный': '-'},
#   'Причастия, %': {'Истероид': 'Больше среднего: (2.17, 3.53)',
#    'Гипертим': 'Меньше среднего: (0.0, 0.0)',
#    'Шизоид': 'Много: (3.53, 18.42)',
#    'Параноял': '-',
#    'Эпилептоид': 'Мало: (0.0, 0.0)',
#    'Депрессивный': '-',
#    'Эмотив': 'Мало: (0.0, 0.0)',
#    'Тревожный': '-'},
#   'Деепричастия, %': {'Истероид': 'Больше среднего: (0.0, 0.0)',
#    'Гипертим': 'Меньше среднего: (0.0, 0.0)',
#    'Шизоид': 'Много: (0.0, 9.09)',
#    'Параноял': '-',
#    'Эпилептоид': 'Мало: (0.0, 0.0)',
#    'Депрессивный': '-',
#    'Эмотив': 'Мало: (0.0, 0.0)',
#    'Тревожный': '-'},
#   'Наклонения, %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Изъявительное наклонение, %': {'Истероид': 'Много: (100.0, 100.0)',
#    'Гипертим': 'Мало: (0.0, 66.67)',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': 'Много: (100.0, 100.0)',
#    'Тревожный': 'Много: (100.0, 100.0)'},
#   'Условное наклонение, %': {'Истероид': 'Среднее: (0.0, 0.0)',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': 'Мало: (0.0, 0.0)',
#    'Депрессивный': '-',
#    'Эмотив': 'Много: (12.5, 50.0)',
#    'Тревожный': '-'},
#   'Повелительное наклонение, %': {'Истероид': 'Мало: (0.0, 0.0)',
#    'Гипертим': '-',
#    'Шизоид': 'Мало: (0.0, 0.0)',
#    'Параноял': 'Много: (0.0, 40.0)',
#    'Эпилептоид': 'Много: (0.0, 40.0)',
#    'Депрессивный': '-',
#    'Эмотив': 'Мало: (0.0, 0.0)',
#    'Тревожный': 'Мало: (0.0, 0.0)'},
#   'Среднее количество слов в предложении': {'Истероид': 'Больше среднего: (12.47, 16.33)',
#    'Гипертим': '-',
#    'Шизоид': 'Много: (16.33, 63.0)',
#    'Параноял': '-',
#    'Эпилептоид': 'Мало: (4.0, 8.0)',
#    'Депрессивный': '-',
#    'Эмотив': 'Меньше среднего: (8.0, 9.82)',
#    'Тревожный': '-'},
#   'Средняя доля именованных сущностей в предложении': {'Истероид': 'Много: (0.5, 3.83)',
#    'Гипертим': 'Среднее: (0.0, 0.2)',
#    'Шизоид': 'Мало: (0.0, 0.0)',
#    'Параноял': 'Мало: (0.0, 0.0)',
#    'Эпилептоид': 'Мало: (0.0, 0.0)',
#    'Депрессивный': '-',
#    'Эмотив': 'Много: (0.5, 3.83)',
#    'Тревожный': 'Среднее: (0.0, 0.2)'},
#   'Среднее количество морфем в слове': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Средняя частота TOP10 самых редких слов в тексте': {'Истероид': 'Больше среднего: (3.02, 3.26)',
#    'Гипертим': '-',
#    'Шизоид': 'Много: (3.26, 5.69)',
#    'Параноял': '-',
#    'Эпилептоид': 'Мало: (0.67, 2.46)',
#    'Депрессивный': '-',
#    'Эмотив': 'Меньше среднего: (2.46, 2.8)',
#    'Тревожный': '-'},
#   'Среднее число синтаксических веток (по предложениям)': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Среднее число синтаксических веток (на одно слово)': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Средняя глубина синтаксической ветки': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Среднее число прилагательных в синтаксической ветке': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Среднее число причастий в синтаксической ветке': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Среднее число деепричастий в синтаксической ветке': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Водность текста': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Вариабельность словаря': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля повторов в тексте': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля местоимений Я': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Классическая тошнота': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Академическая тошнота': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля местоимений в тексте': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля частиц в тексте': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Собственные/Нарицательные': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля числительных в тексте': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля междометий в тексте': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля союзов в тексте': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля предлогов в тексте': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Прошедшее, %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Настоящее, %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Будущее, %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Абсолютное, %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'}},
#  'Морфология, синтаксис, семантика': {'Текст': 'Программа "Вернём клиентов" для дилеров ГаражТулс.В рамках развития дилерской сети за дополнительные деньги настроить триггерную рассылку для тех клиентов, которые ушли.Тестируем: берем лояльного дилера, предлагаем в качестве эксперимента предоставить нам клиентов, которые отказались от покупки (на их сайте или магазине). Собираем контакты, настраиваем триггерную рассылку. Смотрим на результат. Если успех, то проводим опрос на основных дилерах и показываем успешный кейс. Узнаем, сколько бы они заплатили за это. Дальше пробуем продать 2-3- дилерам такую услугу. (пока делаем всё вручную) Если они оплачивают, то гипотезу можно считать проверенной и можно запускать в разработку функционал.(и если юнит экономика сходится)Подключаем дилерскую CRM (или любую другую систему, где есть отвалившиеся клиенты) к системе триггерных рассылок. К пакету дилерских документов предлагаем новую услугу. Непринужденно зарабатываем.',
#   'Общее количество слов в тексте': 100,
#   'Доля предложений на одно слово': 0.11,
#   'Доля коротких предложений': 0.64,
#   'Доля длинных предложений': 0.36,
#   'Доля длинных низкочастотных слов': 0.12,
#   'Доля коротких высокочастотных слов': 0.42,
#   'Средняя длина предложения': 9.09,
#   'Среднее число запятых в предложении': 0.73,
#   'Доля сложноподчиненных предложений': 0.45,
#   'Доля восклицательных предложений': 0.0,
#   'Доля вопросительных предложений': 0.0,
#   'Доля частиц НЕ': 0.0,
#   'Cредняя длинна слова в тексте': 7.17,
#   'Cредняя длинна слова по предложениям': [8.0,
#    7.0,
#    8.0,
#    9.0,
#    8.0,
#    7.0,
#    5.0,
#    5.0,
#    7.0,
#    8.0,
#    12.0],
#   'Гласные, %': 41,
#   'Гласная "И", %': 7,
#   'Гласная "О", %': 8,
#   'Гласная "А", %': 8,
#   'Согласные, %': 57,
#   'Существительные, %': 37.0,
#   'Глаголы, %': 16.0,
#   'Совершенный вид, %': 56.25,
#   'Несовершенный вид, %': 43.75,
#   'Прилагательные, %': 13.0,
#   'Степени сравнения, %': 7.69,
#   'Превосходная степень, %': 0.0,
#   'Сравнительная степень, %': 100.0,
#   'Наречия, %': 5.0,
#   'Причастия, %': 11.0,
#   'Деепричастия, %': 0.0,
#   'Наклонения, %': 22.0,
#   'Изъявительное наклонение, %': 95.45,
#   'Условное наклонение, %': 4.55,
#   'Повелительное наклонение, %': 0.0,
#   'Среднее количество слов в предложении': 9.09,
#   'Средняя доля именованных сущностей в предложении': 0.18,
#   'Среднее количество морфем в слове': 2.35,
#   'Сентименты каждой трети текста и по тексту целиком': ({'neutral': 0.7490972280502319,
#     'negative': 0.22271016240119934,
#     'skip': 0.056662432849407196,
#     'positive': 0.028446035459637642,
#     'speech': 0.009718479588627815},
#    {'neutral': 0.839743971824646,
#     'negative': 0.11280541121959686,
#     'skip': 0.07808816432952881,
#     'positive': 0.01591639406979084,
#     'speech': 0.004765199031680822},
#    {'neutral': 0.8439050912857056,
#     'negative': 0.08757384121417999,
#     'skip': 0.06372499465942383,
#     'positive': 0.03964884206652641,
#     'speech': 0.0032830648124217987},
#    {'neutral': 0.8031837940216064,
#     'negative': 0.14805719256401062,
#     'skip': 0.0695517510175705,
#     'positive': 0.028446035459637642,
#     'speech': 0.006702851038426161}),
#   'Средняя частота TOP10 самых редких слов в тексте': 1.39,
#   'Среднее число синтаксических веток (по предложениям)': 3.18,
#   'Среднее число синтаксических веток (на одно слово)': 2.93,
#   'Средняя глубина синтаксической ветки': 5.0,
#   'Среднее число прилагательных в синтаксической ветке': 0.31,
#   'Среднее число причастий в синтаксической ветке': 0.0,
#   'Среднее число деепричастий в синтаксической ветке': 0.04,
#   'Водность текста': 0.11,
#   'Вариабельность словаря': 0.82,
#   'Доля повторов в тексте': 0.11,
#   'Доля местоимений Я': 0.0,
#   'Классическая тошнота': 0.02,
#   'Академическая тошнота': 0.25,
#   'Доля местоимений в тексте': 0.07,
#   'Доля частиц в тексте': 0.0,
#   'Собственные/Нарицательные': 0.03,
#   'Доля числительных в тексте': 0.03,
#   'Доля междометий в тексте': 0.0,
#   'Доля союзов в тексте': 0.05,
#   'Доля предлогов в тексте': 0.13},
#  'Времена глаголов': {'Текст': 'Программа "Вернём клиентов" для дилеров ГаражТулс.В рамках развития дилерской сети за дополнительные деньги настроить триггерную рассылку для тех клиентов, которые ушли.Тестируем: берем лояльного дилера, предлагаем в качестве эксперимента предоставить нам клиентов, которые отказались от покупки (на их сайте или магазине). Собираем контакты, настраиваем триггерную рассылку. Смотрим на результат. Если успех, то проводим опрос на основных дилерах и показываем успешный кейс. Узнаем, сколько бы они заплатили за это. Дальше пробуем продать 2-3- дилерам такую услугу. (пока делаем всё вручную) Если они оплачивают, то гипотезу можно считать проверенной и можно запускать в разработку функционал.(и если юнит экономика сходится)Подключаем дилерскую CRM (или любую другую систему, где есть отвалившиеся клиенты) к системе триггерных рассылок. К пакету дилерских документов предлагаем новую услугу. Непринужденно зарабатываем.',
#   'Прошедшее, %': 18.8,
#   'Настоящее, %': 31.2,
#   'Будущее, %': 18.8,
#   'Абсолютное, %': 31.2,
#   'Прошедшее, слова': ['ушли', 'отказались', 'заплатили'],
#   'Настоящее, слова': ['берем', 'Смотрим', 'оплачивают', 'сходится', 'есть'],
#   'Будущее, слова': ['Вернём', 'проводим', 'Узнаем'],
#   'Абсолютное, слова': ['настроить',
#    'предоставить',
#    'продать',
#    'считать',
#    'запускать']},
#  'Агенсность, Предикаты': {'Текст': 'Программа "Вернём клиентов" для дилеров ГаражТулс.В рамках развития дилерской сети за дополнительные деньги настроить триггерную рассылку для тех клиентов, которые ушли.Тестируем: берем лояльного дилера, предлагаем в качестве эксперимента предоставить нам клиентов, которые отказались от покупки (на их сайте или магазине). Собираем контакты, настраиваем триггерную рассылку. Смотрим на результат. Если успех, то проводим опрос на основных дилерах и показываем успешный кейс. Узнаем, сколько бы они заплатили за это. Дальше пробуем продать 2-3- дилерам такую услугу. (пока делаем всё вручную) Если они оплачивают, то гипотезу можно считать проверенной и можно запускать в разработку функционал.(и если юнит экономика сходится)Подключаем дилерскую CRM (или любую другую систему, где есть отвалившиеся клиенты) к системе триггерных рассылок. К пакету дилерских документов предлагаем новую услугу. Непринужденно зарабатываем.',
#   'Агенс': 0.0,
#   'Пациенс': 1.0,
#   'Внутренний предикат': 0.0,
#   'Внешний предикат': 0.6,
#   'Агенс, конструкции': [[]],
#   'Пациенс, конструкции': [[('Вернём',),
#     ('настроить',),
#     ('ушли',),
#     ('Тестируем',),
#     ('берем',),
#     ('предлагаем',),
#     ('предоставить',),
#     ('отказались',),
#     ('Собираем',),
#     ('настраиваем',),
#     ('Смотрим',),
#     ('проводим',),
#     ('показываем',),
#     ('Узнаем',),
#     ('заплатили',),
#     ('пробуем',),
#     ('продать',),
#     ('делаем',),
#     ('оплачивают',),
#     ('считать',),
#     ('запускать',),
#     ('есть',),
#     ('предлагаем',),
#     ('зарабатываем',)]],
#   'Внутренний предикат, конструкции': [[('считать',)]],
#   'Внешний предикат, конструкции': [[('Вернём',),
#     ('ушли',),
#     ('берем',),
#     ('Собираем',),
#     ('настраиваем',),
#     ('Смотрим',),
#     ('проводим',),
#     ('показываем',),
#     ('заплатили',),
#     ('пробуем',),
#     ('делаем',),
#     ('оплачивают',),
#     ('считать',),
#     ('запускать',),
#     ('есть',),
#     ('зарабатываем',)]],
#   'Агенс, индексы': [[]],
#   'Пациенс, индексы': [[(2,),
#     (17,),
#     (25,),
#     (27,),
#     (29,),
#     (33,),
#     (37,),
#     (42,),
#     (53,),
#     (56,),
#     (60,),
#     (68,),
#     (74,),
#     (78,),
#     (83,),
#     (88,),
#     (89,),
#     (99,),
#     (105,),
#     (110,),
#     (114,),
#     (131,),
#     (144,),
#     (149,)]],
#   'Внутренний предикат, индексы': [[(110,)]],
#   'Внешний предикат, индексы': [[(2,),
#     (25,),
#     (29,),
#     (53,),
#     (56,),
#     (60,),
#     (68,),
#     (74,),
#     (83,),
#     (88,),
#     (99,),
#     (105,),
#     (110,),
#     (114,),
#     (131,),
#     (149,)]]},
#  'Модальности': {'Текст': 'Программа "Вернём клиентов" для дилеров ГаражТулс.В рамках развития дилерской сети за дополнительные деньги настроить триггерную рассылку для тех клиентов, которые ушли.Тестируем: берем лояльного дилера, предлагаем в качестве эксперимента предоставить нам клиентов, которые отказались от покупки (на их сайте или магазине). Собираем контакты, настраиваем триггерную рассылку. Смотрим на результат. Если успех, то проводим опрос на основных дилерах и показываем успешный кейс. Узнаем, сколько бы они заплатили за это. Дальше пробуем продать 2-3- дилерам такую услугу. (пока делаем всё вручную) Если они оплачивают, то гипотезу можно считать проверенной и можно запускать в разработку функционал.(и если юнит экономика сходится)Подключаем дилерскую CRM (или любую другую систему, где есть отвалившиеся клиенты) к системе триггерных рассылок. К пакету дилерских документов предлагаем новую услугу. Непринужденно зарабатываем.',
#   'Оптативная': 1,
#   'Гипотетическая и потенциальная': 2,
#   'Интенция': 2,
#   'Императив и дебитив': 6,
#   'Оптативная, конструкции': ['бы'],
#   'Гипотетическая и потенциальная, конструкции': ['можно', 'можно'],
#   'Интенция, конструкции': ['Если', 'Если'],
#   'Императив и дебитив, конструкции': ['Вернём',
#    'настроить',
#    'ушли',
#    'предоставить',
#    'отказались',
#    'продать'],
#   'Оптативная, индексы': [81],
#   'Гипотетическая и потенциальная, индексы': [110, 114],
#   'Интенция, индексы': [64, 104],
#   'Императив и дебитив, индексы': [2, 17, 25, 37, 42, 89]},
#  'Разметка шкал "Локльная/Глобальная" и "Хаотичная/Системная"': {'Текст': 'Программа "Вернём клиентов" для дилеров ГаражТулс.В рамках развития дилерской сети за дополнительные деньги настроить триггерную рассылку для тех клиентов, которые ушли.Тестируем: берем лояльного дилера, предлагаем в качестве эксперимента предоставить нам клиентов, которые отказались от покупки (на их сайте или магазине). Собираем контакты, настраиваем триггерную рассылку. Смотрим на результат. Если успех, то проводим опрос на основных дилерах и показываем успешный кейс. Узнаем, сколько бы они заплатили за это. Дальше пробуем продать 2-3- дилерам такую услугу. (пока делаем всё вручную) Если они оплачивают, то гипотезу можно считать проверенной и можно запускать в разработку функционал.(и если юнит экономика сходится)Подключаем дилерскую CRM (или любую другую систему, где есть отвалившиеся клиенты) к системе триггерных рассылок. К пакету дилерских документов предлагаем новую услугу. Непринужденно зарабатываем.',
#   'Глаголы': 1,
#   'Прилагательные': 0,
#   'Наречия': 0,
#   'Деепричастия': 0,
#   'Причастия': 1,
#   'Совершенная форма': 1,
#   'Несовершенная форма': 0,
#   'Простые предложения': 1,
#   'Сложные предложения': 0,
#   'Гласные': 0,
#   'Согласные': 1,
#   'Условное наклонение': 1,
#   'Повелительное наклонение': 0,
#   'Частица НЕ': 0,
#   'Оптативная': 1,
#   'Гипотетическая и потенциальная': 1,
#   'Интенция': 1,
#   'Императив и дебитив': 1,
#   'Агенс': 0,
#   'Пациенс': 1,
#   'Хаос': 50,
#   'Система': 62,
#   'Локальная': 71,
#   'Глобальная': 43,
#   'Хаос / Система': 2,
#   'Локальная / Глобальная': 0},
#  'Индикаторы психотипов в разрезе признаков по тексту': {'Общее количество слов в тексте': {'Значение': 100.0,
#    'Количество': 'Много',
#    'Диапазон': (61.8, 151),
#    'Психотип': []},
#   'Доля предложений на одно слово': {'Значение': 0.11,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.1, 0.12),
#    'Психотип': ['Истероид']},
#   'Доля коротких предложений': {'Значение': 0.64,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.5, 0.75),
#    'Психотип': []},
#   'Доля длинных предложений': {'Значение': 0.36,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (0.25, 0.44),
#    'Психотип': []},
#   'Доля длинных низкочастотных слов': {'Значение': 0.12,
#    'Количество': 'Среднее',
#    'Диапазон': (0.11, 0.13),
#    'Психотип': []},
#   'Доля коротких высокочастотных слов': {'Значение': 0.42,
#    'Количество': 'Мало',
#    'Диапазон': (0.27, 0.43),
#    'Психотип': ['Шизоид', 'Тревожный']},
#   'Средняя длина предложения': {'Значение': 9.09,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (8.0, 9.82),
#    'Психотип': ['Эмотив']},
#   'Среднее число запятых в предложении': {'Значение': 0.73,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (0.43, 0.8),
#    'Психотип': []},
#   'Доля сложноподчиненных предложений': {'Значение': 0.45,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.29, 0.5),
#    'Психотип': []},
#   'Доля восклицательных предложений': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Психотип': []},
#   'Доля вопросительных предложений': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Психотип': []},
#   'Доля частиц НЕ': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Психотип': []},
#   'Cредняя длинна слова в тексте': {'Значение': 7.17,
#    'Количество': 'Среднее',
#    'Диапазон': (6.95, 7.32),
#    'Психотип': []},
#   'Гласные, %': {'Значение': 41.0,
#    'Количество': 'Мало',
#    'Диапазон': (36, 41.0),
#    'Психотип': ['Параноял']},
#   'Гласная "И", %': {'Значение': 7.0,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (6.0, 7.0),
#    'Психотип': []},
#   'Гласная "О", %': {'Значение': 8.0,
#    'Количество': 'Мало',
#    'Диапазон': (6, 9.0),
#    'Психотип': []},
#   'Гласная "А", %': {'Значение': 8.0,
#    'Количество': 'Среднее',
#    'Диапазон': (7.0, 8.0),
#    'Психотип': []},
#   'Согласные, %': {'Значение': 57.0,
#    'Количество': 'Больше среднего',
#    'Диапазон': (56.0, 57.0),
#    'Психотип': ['Шизоид', 'Эпилептоид']},
#   'Существительные, %': {'Значение': 37.0,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (35.43, 42.44),
#    'Психотип': []},
#   'Глаголы, %': {'Значение': 16.0,
#    'Количество': 'Среднее',
#    'Диапазон': (15.62, 19.66),
#    'Психотип': []},
#   'Совершенный вид, %': {'Значение': 56.25,
#    'Количество': 'Среднее',
#    'Диапазон': (50.91, 69.13),
#    'Психотип': []},
#   'Несовершенный вид, %': {'Значение': 43.75,
#    'Количество': 'Больше среднего',
#    'Диапазон': (40.73, 66.67),
#    'Психотип': ['Истероид', 'Эмотив']},
#   'Прилагательные, %': {'Значение': 13.0,
#    'Количество': 'Больше среднего',
#    'Диапазон': (12.5, 15.48),
#    'Психотип': []},
#   'Степени сравнения, %': {'Значение': 7.69,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.0, 13.22),
#    'Психотип': []},
#   'Превосходная степень, %': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Психотип': []},
#   'Сравнительная степень, %': {'Значение': 100.0,
#    'Количество': 'Много',
#    'Диапазон': (50.0, 100.0),
#    'Психотип': []},
#   'Наречия, %': {'Значение': 5.0,
#    'Количество': 'Среднее',
#    'Диапазон': (3.14, 5.54),
#    'Психотип': []},
#   'Причастия, %': {'Значение': 11.0,
#    'Количество': 'Много',
#    'Диапазон': (3.53, 18.42),
#    'Психотип': ['Шизоид']},
#   'Деепричастия, %': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Психотип': []},
#   'Наклонения, %': {'Значение': 22.0,
#    'Количество': 'Много',
#    'Диапазон': (9.0, 23.0),
#    'Психотип': []},
#   'Изъявительное наклонение, %': {'Значение': 95.45,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (66.67, 100.0),
#    'Психотип': []},
#   'Условное наклонение, %': {'Значение': 4.55,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.0, 12.5),
#    'Психотип': []},
#   'Повелительное наклонение, %': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Психотип': []},
#   'Среднее количество слов в предложении': {'Значение': 9.09,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (8.0, 9.82),
#    'Психотип': ['Эмотив']},
#   'Средняя доля именованных сущностей в предложении': {'Значение': 0.18,
#    'Количество': 'Среднее',
#    'Диапазон': (0.0, 0.2),
#    'Психотип': ['Гипертим', 'Тревожный']},
#   'Среднее количество морфем в слове': {'Значение': 2.35,
#    'Количество': 'Мало',
#    'Диапазон': (1.88, 2.38),
#    'Психотип': []},
#   'Средняя частота TOP10 самых редких слов в тексте': {'Значение': 1.39,
#    'Количество': 'Мало',
#    'Диапазон': (0.67, 2.46),
#    'Психотип': ['Эпилептоид']},
#   'Среднее число синтаксических веток (по предложениям)': {'Значение': 3.18,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (3.0, 3.5),
#    'Психотип': []},
#   'Среднее число синтаксических веток (на одно слово)': {'Значение': 2.93,
#    'Количество': 'Среднее',
#    'Диапазон': (2.82, 3.02),
#    'Психотип': []},
#   'Средняя глубина синтаксической ветки': {'Значение': 5.0,
#    'Количество': 'Среднее',
#    'Диапазон': (4.82, 5.5),
#    'Психотип': []},
#   'Среднее число прилагательных в синтаксической ветке': {'Значение': 0.31,
#    'Количество': 'Среднее',
#    'Диапазон': (0.27, 0.39),
#    'Психотип': []},
#   'Среднее число причастий в синтаксической ветке': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Психотип': []},
#   'Среднее число деепричастий в синтаксической ветке': {'Значение': 0.04,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.03, 0.08),
#    'Психотип': []},
#   'Водность текста': {'Значение': 0.11,
#    'Количество': 'Среднее',
#    'Диапазон': (0.1, 0.14),
#    'Психотип': []},
#   'Вариабельность словаря': {'Значение': 0.82,
#    'Количество': 'Среднее',
#    'Диапазон': (0.82, 0.86),
#    'Психотип': []},
#   'Доля повторов в тексте': {'Значение': 0.11,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (0.08, 0.11),
#    'Психотип': []},
#   'Доля местоимений Я': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Психотип': []},
#   'Классическая тошнота': {'Значение': 0.02,
#    'Количество': 'Мало',
#    'Диапазон': (0.01, 0.03),
#    'Психотип': []},
#   'Академическая тошнота': {'Значение': 0.25,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.22, 0.26),
#    'Психотип': []},
#   'Доля местоимений в тексте': {'Значение': 0.07,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.06, 0.09),
#    'Психотип': []},
#   'Доля частиц в тексте': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Психотип': []},
#   'Собственные/Нарицательные': {'Значение': 0.03,
#    'Количество': 'Много',
#    'Диапазон': (0.0, 0.14),
#    'Психотип': []},
#   'Доля числительных в тексте': {'Значение': 0.03,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.0, 0.04),
#    'Психотип': []},
#   'Доля междометий в тексте': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Психотип': []},
#   'Доля союзов в тексте': {'Значение': 0.05,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (0.03, 0.05),
#    'Психотип': []},
#   'Доля предлогов в тексте': {'Значение': 0.13,
#    'Количество': 'Среднее',
#    'Диапазон': (0.12, 0.15),
#    'Психотип': []},
#   'Агенс': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Психотип': []},
#   'Пациенс': {'Значение': 1.0,
#    'Количество': 'Среднее',
#    'Диапазон': (0.8, 1.0),
#    'Психотип': ['Шизоид']},
#   'Внутренний предикат': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Психотип': []},
#   'Внешний предикат': {'Значение': 0.6,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.4, 0.6),
#    'Психотип': ['Тревожный', 'Эмотив']}},
#  'Индикаторы психотипов в разрезе признаков по тексту (альтернативный формат)': {'Общее количество слов в тексте': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля предложений на одно слово': {'Истероид': 'Больше среднего: 0.11 из (0.1, 0.12)',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля коротких предложений': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля длинных предложений': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля длинных низкочастотных слов': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля коротких высокочастотных слов': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': 'Мало: 0.42 из (0.27, 0.43)',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': 'Мало: 0.42 из (0.27, 0.43)'},
#   'Средняя длина предложения': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': 'Меньше среднего: 9.09 из (8.0, 9.82)',
#    'Тревожный': '-'},
#   'Среднее число запятых в предложении': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля сложноподчиненных предложений': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля восклицательных предложений': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля вопросительных предложений': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Доля частиц НЕ': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Cредняя длинна слова в тексте': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Гласные, %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': 'Мало: 41 из (36, 41.0)',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Гласная "И", %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Гласная "О", %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Гласная "А", %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': '-',
#    'Параноял': '-',
#    'Эпилептоид': '-',
#    'Депрессивный': '-',
#    'Эмотив': '-',
#    'Тревожный': '-'},
#   'Согласные, %': {'Истероид': '-',
#    'Гипертим': '-',
#    'Шизоид': 'Больше среднего: 57 из (56.0, 57.0)',
#    'Параноял': '-',
# ...
#    'Количество': 'Меньше среднего',
#    'Диапазон': (0.43, 0.8),
#    'Темперамент': []},
#   'Доля сложноподчиненных предложений': {'Значение': 0.45,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.29, 0.5),
#    'Темперамент': []},
#   'Доля восклицательных предложений': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Темперамент': []},
#   'Доля вопросительных предложений': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Темперамент': []},
#   'Доля частиц НЕ': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Темперамент': []},
#   'Cредняя длинна слова в тексте': {'Значение': 7.17,
#    'Количество': 'Среднее',
#    'Диапазон': (6.95, 7.32),
#    'Темперамент': []},
#   'Гласные, %': {'Значение': 41.0,
#    'Количество': 'Мало',
#    'Диапазон': (36, 41.0),
#    'Темперамент': []},
#   'Гласная "И", %': {'Значение': 7.0,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (6.0, 7.0),
#    'Темперамент': []},
#   'Гласная "О", %': {'Значение': 8.0,
#    'Количество': 'Мало',
#    'Диапазон': (6, 9.0),
#    'Темперамент': []},
#   'Гласная "А", %': {'Значение': 8.0,
#    'Количество': 'Среднее',
#    'Диапазон': (7.0, 8.0),
#    'Темперамент': []},
#   'Согласные, %': {'Значение': 57.0,
#    'Количество': 'Больше среднего',
#    'Диапазон': (56.0, 57.0),
#    'Темперамент': ['Сангвиник', 'Флегматик']},
#   'Существительные, %': {'Значение': 37.0,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (35.43, 42.44),
#    'Темперамент': ['Холерик']},
#   'Глаголы, %': {'Значение': 16.0,
#    'Количество': 'Среднее',
#    'Диапазон': (15.62, 19.66),
#    'Темперамент': ['Холерик']},
#   'Совершенный вид, %': {'Значение': 56.25,
#    'Количество': 'Среднее',
#    'Диапазон': (50.91, 69.13),
#    'Темперамент': []},
#   'Несовершенный вид, %': {'Значение': 43.75,
#    'Количество': 'Больше среднего',
#    'Диапазон': (40.73, 66.67),
#    'Темперамент': ['Холерик', 'Меланхолик']},
#   'Прилагательные, %': {'Значение': 13.0,
#    'Количество': 'Больше среднего',
#    'Диапазон': (12.5, 15.48),
#    'Темперамент': ['Флегматик']},
#   'Степени сравнения, %': {'Значение': 7.69,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.0, 13.22),
#    'Темперамент': []},
#   'Превосходная степень, %': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Темперамент': []},
#   'Сравнительная степень, %': {'Значение': 100.0,
#    'Количество': 'Много',
#    'Диапазон': (50.0, 100.0),
#    'Темперамент': []},
#   'Наречия, %': {'Значение': 5.0,
#    'Количество': 'Среднее',
#    'Диапазон': (3.14, 5.54),
#    'Темперамент': ['Флегматик']},
#   'Причастия, %': {'Значение': 11.0,
#    'Количество': 'Много',
#    'Диапазон': (3.53, 18.42),
#    'Темперамент': ['Сангвиник']},
#   'Деепричастия, %': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Темперамент': []},
#   'Наклонения, %': {'Значение': 22.0,
#    'Количество': 'Много',
#    'Диапазон': (9.0, 23.0),
#    'Темперамент': []},
#   'Изъявительное наклонение, %': {'Значение': 95.45,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (66.67, 100.0),
#    'Темперамент': []},
#   'Условное наклонение, %': {'Значение': 4.55,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.0, 12.5),
#    'Темперамент': []},
#   'Повелительное наклонение, %': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Темперамент': []},
#   'Среднее количество слов в предложении': {'Значение': 9.09,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (8.0, 9.82),
#    'Темперамент': ['Меланхолик']},
#   'Средняя доля именованных сущностей в предложении': {'Значение': 0.18,
#    'Количество': 'Среднее',
#    'Диапазон': (0.0, 0.2),
#    'Темперамент': []},
#   'Среднее количество морфем в слове': {'Значение': 2.35,
#    'Количество': 'Мало',
#    'Диапазон': (1.88, 2.38),
#    'Темперамент': []},
#   'Средняя частота TOP10 самых редких слов в тексте': {'Значение': 1.39,
#    'Количество': 'Мало',
#    'Диапазон': (0.67, 2.46),
#    'Темперамент': ['Флегматик']},
#   'Среднее число синтаксических веток (по предложениям)': {'Значение': 3.18,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (3.0, 3.5),
#    'Темперамент': []},
#   'Среднее число синтаксических веток (на одно слово)': {'Значение': 2.93,
#    'Количество': 'Среднее',
#    'Диапазон': (2.82, 3.02),
#    'Темперамент': []},
#   'Средняя глубина синтаксической ветки': {'Значение': 5.0,
#    'Количество': 'Среднее',
#    'Диапазон': (4.82, 5.5),
#    'Темперамент': []},
#   'Среднее число прилагательных в синтаксической ветке': {'Значение': 0.31,
#    'Количество': 'Среднее',
#    'Диапазон': (0.27, 0.39),
#    'Темперамент': []},
#   'Среднее число причастий в синтаксической ветке': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Темперамент': []},
#   'Среднее число деепричастий в синтаксической ветке': {'Значение': 0.04,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.03, 0.08),
#    'Темперамент': []},
#   'Водность текста': {'Значение': 0.11,
#    'Количество': 'Среднее',
#    'Диапазон': (0.1, 0.14),
#    'Темперамент': []},
#   'Вариабельность словаря': {'Значение': 0.82,
#    'Количество': 'Среднее',
#    'Диапазон': (0.82, 0.86),
#    'Темперамент': []},
#   'Доля повторов в тексте': {'Значение': 0.11,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (0.08, 0.11),
#    'Темперамент': []},
#   'Доля местоимений Я': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Темперамент': []},
#   'Классическая тошнота': {'Значение': 0.02,
#    'Количество': 'Мало',
#    'Диапазон': (0.01, 0.03),
#    'Темперамент': []},
#   'Академическая тошнота': {'Значение': 0.25,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.22, 0.26),
#    'Темперамент': []},
#   'Доля местоимений в тексте': {'Значение': 0.07,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.06, 0.09),
#    'Темперамент': ['Флегматик']},
#   'Доля частиц в тексте': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Темперамент': []},
#   'Собственные/Нарицательные': {'Значение': 0.03,
#    'Количество': 'Много',
#    'Диапазон': (0.0, 0.14),
#    'Темперамент': []},
#   'Доля числительных в тексте': {'Значение': 0.03,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.0, 0.04),
#    'Темперамент': ['Флегматик', 'Холерик']},
#   'Доля междометий в тексте': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Темперамент': []},
#   'Доля союзов в тексте': {'Значение': 0.05,
#    'Количество': 'Меньше среднего',
#    'Диапазон': (0.03, 0.05),
#    'Темперамент': []},
#   'Доля предлогов в тексте': {'Значение': 0.13,
#    'Количество': 'Среднее',
#    'Диапазон': (0.12, 0.15),
#    'Темперамент': []},
#   'Агенс': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Темперамент': []},
#   'Пациенс': {'Значение': 1.0,
#    'Количество': 'Среднее',
#    'Диапазон': (0.8, 1.0),
#    'Темперамент': ['Сангвиник']},
#   'Внутренний предикат': {'Значение': 0.0,
#    'Количество': 'Нет',
#    'Диапазон': (0, 0.0),
#    'Темперамент': []},
#   'Внешний предикат': {'Значение': 0.6,
#    'Количество': 'Больше среднего',
#    'Диапазон': (0.4, 0.6),
#    'Темперамент': ['Меланхолик']}},
#  'Индикаторы темпераментов в разрезе признаков по тексту (альтернативный формат)': {'Общее количество слов в тексте': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля предложений на одно слово': {'Меланхолик': '-',
#    'Холерик': 'Больше среднего: 0.11 из (0.1, 0.12)',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля коротких предложений': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля длинных предложений': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля длинных низкочастотных слов': {'Меланхолик': 'Среднее: 0.12 из (0.11, 0.13)',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля коротких высокочастотных слов': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Средняя длина предложения': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее число запятых в предложении': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля сложноподчиненных предложений': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля восклицательных предложений': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля вопросительных предложений': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля частиц НЕ': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Cредняя длинна слова в тексте': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Гласные, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Гласная "И", %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Гласная "О", %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Гласная "А", %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Согласные, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': 'Больше среднего: 57 из (56.0, 57.0)',
#    'Сангвиник': 'Больше среднего: 57 из (56.0, 57.0)'},
#   'Существительные, %': {'Меланхолик': '-',
#    'Холерик': 'Меньше среднего: 37.0 из (35.43, 42.44)',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Глаголы, %': {'Меланхолик': '-',
#    'Холерик': 'Среднее: 16.0 из (15.62, 19.66)',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Совершенный вид, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Несовершенный вид, %': {'Меланхолик': 'Больше среднего: 43.75 из (40.73, 66.67)',
#    'Холерик': 'Больше среднего: 43.75 из (40.73, 66.67)',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Прилагательные, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': 'Больше среднего: 13.0 из (12.5, 15.48)',
#    'Сангвиник': '-'},
#   'Степени сравнения, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Превосходная степень, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Сравнительная степень, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Наречия, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': 'Среднее: 5.0 из (3.14, 5.54)',
#    'Сангвиник': '-'},
#   'Причастия, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': 'Много: 11.0 из (3.53, 18.42)'},
#   'Деепричастия, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Наклонения, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Изъявительное наклонение, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Условное наклонение, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Повелительное наклонение, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее количество слов в предложении': {'Меланхолик': 'Меньше среднего: 9.09 из (8.0, 9.82)',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Средняя доля именованных сущностей в предложении': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее количество морфем в слове': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Средняя частота TOP10 самых редких слов в тексте': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': 'Мало: 1.39 из (0.67, 2.46)',
#    'Сангвиник': '-'},
#   'Среднее число синтаксических веток (по предложениям)': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее число синтаксических веток (на одно слово)': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Средняя глубина синтаксической ветки': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее число прилагательных в синтаксической ветке': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее число причастий в синтаксической ветке': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Среднее число деепричастий в синтаксической ветке': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Водность текста': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Вариабельность словаря': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля повторов в тексте': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля местоимений Я': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Классическая тошнота': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Академическая тошнота': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля местоимений в тексте': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': 'Больше среднего: 0.07 из (0.06, 0.09)',
#    'Сангвиник': '-'},
#   'Доля частиц в тексте': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Собственные/Нарицательные': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля числительных в тексте': {'Меланхолик': '-',
#    'Холерик': 'Больше среднего: 0.03 из (0.0, 0.04)',
#    'Флегматик': 'Больше среднего: 0.03 из (0.0, 0.04)',
#    'Сангвиник': '-'},
#   'Доля междометий в тексте': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля союзов в тексте': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Доля предлогов в тексте': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Агенс': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Пациенс': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': 'Среднее: 1.0 из (0.8, 1.0)'},
#   'Внутренний предикат': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Внешний предикат': {'Меланхолик': 'Больше среднего: 0.6 из (0.4, 0.6)',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Прошедшее, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Настоящее, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Будущее, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'},
#   'Абсолютное, %': {'Меланхолик': '-',
#    'Холерик': '-',
#    'Флегматик': '-',
#    'Сангвиник': '-'}},
#  'Темпераменты': {'Абсолютные значения': {'Холерик': 5,
#    'Меланхолик': 4,
#    'Сангвиник': 3,
#    'Флегматик': 6},
#   'Нормировка по l1-норме': {'Холерик': 0.28,
#    'Меланхолик': 0.22,
#    'Сангвиник': 0.17,
#    'Флегматик': 0.33},
#   'Нормировка по Чебышевской норме': {'Холерик': 0.83,
#    'Меланхолик': 0.67,
#    'Сангвиник': 0.5,
#    'Флегматик': 1.0}},
#  'Индикаторы шкалы "Хаотичная/Системная" с обратными квантилями': {'Доля гласных / Доля согласных': {'Значение': 2,
#    'Обратный квантиль': 0.1},
#   'Несовершенный вид / Совершенный вид': {'Значение': 1,
#    'Обратный квантиль': 0.65},
#   'Количество глаголов / Количество прилагательных': {'Значение': 1,
#    'Обратный квантиль': 0.38},
#   'Количество наречий / Количество деепричастий': {'Значение': 1,
#    'Обратный квантиль': 0.51},
#   'Количество причастий / Количество деепричастий': {'Значение': 0,
#    'Обратный квантиль': 1.0},
#   'Доля условного наклонения / Доля повелительного наклонения': {'Значение': 0,
#    'Обратный квантиль': 0.7},
#   'Доля частиц НЕ среди всех слов': {'Значение': 1, 'Обратный квантиль': 0.18},
#   'Хаотичная/Системная': {'Значение': 0, 'Обратный квантиль': -1.0}}}

# %%
print(dict_res.keys())
# Out:
# dict_keys(['Текст', 'Интервалы для темпераментов', 'Интервалы для психотипов', 'Морфология, синтаксис, семантика', 'Времена глаголов', 'Агенсность, Предикаты', 'Модальности', 'Разметка шкал "Локльная/Глобальная" и "Хаотичная/Системная"', 'Индикаторы психотипов в разрезе признаков по тексту', 'Индикаторы психотипов в разрезе признаков по тексту (альтернативный формат)', 'Психотипы', 'Индекс близости к 4 психотипам', 'Психотипы по ELMO', 'Индикаторы темпераментов в разрезе признаков по тексту', 'Индикаторы темпераментов в разрезе признаков по тексту (альтернативный формат)', 'Темпераменты', 'Индикаторы шкалы "Хаотичная/Системная" с обратными квантилями'])
